# %% [markdown]
# # **I. Essai 1 avec DBeaver**

# %% [markdown]
# # **1. Télécharger JDBC Driver Jar**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2. Télécharger DBeaver pour faire fonctionner le driver JDBC de cassanda et tester la communication**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Importation du pilote JDBC dans DBeaver**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # cliquez sur Gestionnaire de pilotes --> cliquez sur Nouveau --> Remplissez les cases:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Modèles d'URL utilisés :**
#
# `1- jdbc:cassandra://rncp_ol;DefaultKeyspace=ol;AuthMech=2;UID=token PWD=AstraCS:iWxLLtbdWmtgyDZRCpFiItFB:497292480969041cdddd88c6afbc43767302ea5479f5450c4b46da9d9eb8f180;SecureConnectionBundlePath=C:\Users\Administrateur\Downloads\secure-connect-rncp-ol.zip;TunableConsistency=6`
#
# `2- jdbc:cassandra://663963fa-6f41-4552-800d-45c8a1cdf530-1-us-east1.apps.astra.datastax.com:443`
#
# `3- cassandra://datastax-cluster-config-prod.s3.us-east-2.amazonaws.com/663963fa-6f41-4552-800d-45c8a1cdf530-1`

# %% [markdown]
# # **Cliquez sur Bibliothèques --> ajouter le fichier jar "**cassandrajdbc2.3.2.jar**"**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Création d’une connexion Cassandra**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **II. Essai 2 directe avec KNIME**

# %% [markdown]
# # **Cliquez sur File --> Preferences**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Cliquez sur add**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ajoutez URL template --> Add file ( cassandrajdbc2.3.2.jar) --> find driver classes --> ok ***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Cliquez sur apply anc close**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Configurez le noeud DB connector comme suit**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Executez le DB connector --> ERREUR :**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
